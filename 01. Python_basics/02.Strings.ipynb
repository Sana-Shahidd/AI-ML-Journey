# %% [markdown]
# Problem 1 - Print the following pattern. Write a program to use for loop to print the following reverse number pattern.
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %%
for i in range(5,0,-1):
    for j in range(i,0,-1):
        print(j, end=" ")
    print()
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %% [markdown]
# Problem 2: Print the following pattern.
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(1,6):
    for j in range(i):
        print("*", end=" ")
    print()
for k in range(4,0,-1):
    for l in range(k,0,-1):
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# Problem 3:Write a program to pring the following pattern
#     *
#   * * *
# * * * * *

# %%
for i in range(1,4):
    for k in range(3-i):
        print(" ", end=" ")
    for j in range(2*i-1):
        print("*", end=" ")
    print()
# Out:
#     *
#   * * *
# * * * * *

# %% [markdown]
# Problem 7 - Find the sum of the series upto n terms.
# Write a program to calculate the sum of series up to n term. For example, if n =5 the series will become 2 + 22 + 222 + 2222 + 22222 = 24690. Take the user input and then calculate. And the output style should match which is given in the example.
#
# Example 1:
#
# Input:
#
# 5
# Output:
#
# 2+22+222+2222+22222
# Sum of above series is: 24690

# %%
a=int(input("Enter a number: "))
number="2"
sum=0
for i in range(1,6):
    num=(number*i)
    sum+=int(num)
print(sum)
# Out:
# 24690

# %% [markdown]
# Problem 8: Write a program to print all the unique combinations of 1,2,3 and 4
# Output:
#
# 1 2 3 4
# 1 2 4 3
# 1 3 2 4
# 1 3 4 2
# 1 4 2 3
# 1 4 3 2
# 2 1 3 4
# 2 1 4 3
# 2 3 1 4
# 2 3 4 1
# 2 4 1 3
# .
# .
# and so on

# %%
from itertools import permutations
nums = [1, 2, 3, 4]
for p in permutations(nums):
    print(*p)
# Out:
# 1 2 3 4
# 1 2 4 3
# 1 3 2 4
# 1 3 4 2
# 1 4 2 3
# 1 4 3 2
# 2 1 3 4
# 2 1 4 3
# 2 3 1 4
# 2 3 4 1
# 2 4 1 3
# 2 4 3 1
# 3 1 2 4
# 3 1 4 2
# 3 2 1 4
# 3 2 4 1
# 3 4 1 2
# 3 4 2 1
# 4 1 2 3
# 4 1 3 2
# 4 2 1 3
# 4 2 3 1
# 4 3 1 2
# 4 3 2 1

# %% [markdown]
# Problem 9: Write a program that will take a decimal number as input and prints out the binary equivalent of the number

# %%
a=int(input("Enter a decimal number: "))
print(bin(a))
# Out:
# 0b11

# %% [markdown]
# Problem 11: Create Short Form from initial character
# Given a string create short form ofthe string from Initial character. Short form should be capitalised.
#
# Example:
#
# Input:
#
# Data science mentorship program
# Output:
#
# DSMP

# %%
text="Data science mentorship program"
l=text.split()
Short_form=""
for i in l:
    Short_form += i[0].upper()
print(Short_form)
# Out:
# DSMP

# %% [markdown]
# Problem 12: Append second string in the middle of first string
# Input:
#
# campusx
# data
# Output:
#
# camdatapusx

# %%
s1="campusx"
s2="data"
mid=len(s1)//2
result=s1[:mid]+s2+s1[mid: ]
print(result)
# Out:
# camdatapusx

# %% [markdown]
# Problem 13:Given string contains a combination of the lower and upper case letters. Write a program to arrange the characters of a string so that all lowercase letters should come first.
# Given:
#
# str1 = PyNaTive
#
# Expected Output:
#
# yaivePNT

# %%
str1 = "PyNaTive"
s1=[i for i in str1 if i.isupper()]
s2=[i for i in str1 if i.islower()]
s3=s2+s1
print(("".join(s3)))


# s2=(i for i in str1 if i.islower()) #generator
# Out:
# generator

# %% [markdown]
# Problem 14:Take a alphanumeric string input and print the sum and average of the digits that appear in the string, ignoring all other characters.
# Input:
#
# hel123O4every093
#
# Output:
#
# Sum: 22
# Avg: 2.75

# %%
str1="hel123O4every093"
s4=[i for i in str1 if i.isnumeric()] 
s4
for i in s4:
    sum+=int(i)
print(sum)
avg=sum/len(s4)
print(avg)
# Out:
# 22
# 3.142857142857143

# %% [markdown]
# Problem 15: Removal of all characters from a string except integers
# Given:
#
# str1 = 'I am 25 years and 10 months old'
# Expected Output:
#
# 2510

# %%
str1 = 'I am 25 years and 10 months old'
s4=[i for i in str1 if i.isnumeric()] 
ans=int("".join(s4))
ans
# Out:
# 2510

# %% [markdown]
# Problem 16: Check whether the string is Symmetrical.
# Statement: Given a string. the task is to check if the string is symmetrical or not. A string is said to be symmetrical if both the halves of the string are the same.
#
# Example 1:
#
# Input
#
# khokho
# Output
#
# The entered string is symmetrical

# %%
s = input("Enter a string: ")

n = len(s)

if n % 2 != 0:
    print("The entered string is not symmetrical")
else:
    first_half = s[:n//2]
    second_half = s[n//2:]

    if first_half == second_half:
        print("The entered string is symmetrical")
    else:
        print("The entered string is not symmetrical")
# Out:
# The entered string is symmetrical

# %% [markdown]
# Problem 17: Reverse words in a given String
# Statement: We are given a string and we need to reverse words of a given string.
#
# Example 1:
#
# Input:
#
# geeks quiz practice code
# Output:
#
# code practice quiz geeks
# Example 2:
#
# Input:
#
# my name is laxmi
# Output:
#
# laxmi is name my

# %%
str6="geeks quiz practice code"
list=str6.split()
print(list)
Reversed=" ".join(list[::-1])
print(Reversed)
# Out:
# ['geeks', 'quiz', 'practice', 'code']
# code practice quiz geeks

# %% [markdown]
# Problem 18: Find uncommon words from two Strings.
# Statement: Given two sentences as strings A and B. The task is to return a list of all uncommon words. A word is uncommon if it appears exactly once in any one of the sentences, and does not appear in the other sentence. Note: A sentence is a string of space-separated words. Each word consists only of lowercase letters.
#
# Example 1:
#
# Input:
#
# A = "apple banana mango"
# B = "banana fruits mango"
# Output:
#
# ['apple', 'fruits']

# %%
A = "apple banana mango"
B = "banana fruits mango"

words = A.split() + B.split()
uncommon=[word for word in words if words.count(word) == 1]
print(uncommon)
# Out:
# ['apple', 'fruits']

# %%
from collections import Counter

A = "apple banana mango"
B = "banana fruits mango"

words = A.split() + B.split()
freq = Counter(words)
print(freq)
uncommon = [word for word in freq if freq[word] == 1]
print(uncommon)
# Out:
# Counter({'banana': 2, 'mango': 2, 'apple': 1, 'fruits': 1})
# ['apple', 'fruits']

# %% [markdown]
# Problem 19: Word location in String.
# Statement: Find a location of a word in a given sentence.
#
# Example 1:
#
# Input:
#
# Sentence: We can learn data science through campusx mentorship program.
#
# word: campusx
# Output:
#
# Location of the word is 7.
# Note- Don't use index/find functions

# %%
str6 = "We can learn data science through campusx mentorship program."
words = str6.split()

# index = words.index("campusx")
# print(index)

index = [i for i, word in enumerate(words) if word == "campusx"]
print(index[0])
# Out:
# 6
# <enumerate object at 0x000002755CDEF650>

# %%
words = ["apple", "banana", "mango"]

for i, word in enumerate(words):
    print(i, word)
# Out:
# 0 apple
# 1 banana
# 2 mango

# %%
s = input("Enter a string: ")

result = ""
seen = set()

for ch in s:
    if ch not in seen:
        result += ch
        seen.add(ch)

print(result)
# Out:
# progamin
