# %% [markdown]
# What is API

# %% [markdown]
# our daytoday task is dependent on dfferent websites and api help in running those websites.
# Apis are nothing but data pipelines that helps in communication beyween two softwares.
