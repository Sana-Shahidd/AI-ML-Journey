# %% [markdown]
# to functions->export functions

# %%
import pandas as pd
df= pd.DataFrame()
df.to

# %%
movies_df=pd.read_csv("movies.csv")
new_dataset=pd.read_csv("movies.csv", usecols=["title_x","imdb_rating"])
new_dataset.to_csv("moviess.csv", index=False) #index=False removes extra columns

# %% [markdown]
# another way is group by
# * reset_index()-> converts back to dataframe

# %% [markdown]
# * use excel wwriter object of if you want to make multiple files
