# %% [markdown]
# Feature Engineering is the process of using domain knowledge to extract features from raw data. These features are used to improve the performance of machine learning algorithm.

# %%
# features means column

# %% [markdown]
# Feature Engineering has 4 steps
# * Feature Transformation
# 1. missing values interpretation
# 2. Handling Categorical Features
# 3. Outliers Detection
# 4. Feature Scaling (taking the higher values to a lower range like in knn)
# * Feature Construction (create completely new col)
# * Feature Selection (apne im features ko niklte ho)
# * Feature Extraction (completeely new columns create krte ho)

# %%
# sklearn donot accept the missing values
# sklearn only accept numerical values so convert categorical into numerical by making more columns(Hot encoding)
