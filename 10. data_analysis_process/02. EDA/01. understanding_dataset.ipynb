# %% [markdown]
# For understanding the dataset tyou have to ask few question from your data?
# * how big the data is?
# * how does the data looks like?
# * what is the datatypes of columns?
# * ae there any missing values
# * how does data looks mathematically
# * Are thee duplicate values
# * how is the corelation between the columns

# %%
import pandas as pd
movies=pd.read_csv("matches.csv")
movies.shape
# Out:
# (636, 18)

# %%
movies.head()
movies.sample(5) # use this function if you donot want to see the bias
# Out:
#       id  season     city        date                   team1  \
# 554  555    2015  Kolkata  2015-05-04   Kolkata Knight Riders
# 599  600    2016   Mumbai  2016-04-28   Kolkata Knight Riders
# 376  377    2012   Jaipur  2012-05-20        Rajasthan Royals
# 3      4    2017   Indore  2017-04-08  Rising Pune Supergiant
# 271  272    2011  Chennai  2011-05-01     Chennai Super Kings
#
#                    team2          toss_winner toss_decision  result  \
# 554  Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 599       Mumbai Indians       Mumbai Indians         field  normal
# 376       Mumbai Indians     Rajasthan Royals           bat  normal
# 3        Kings XI Punjab      Kings XI Punjab         field  normal
# 271      Deccan Chargers  Chennai Super Kings           bat  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 554           0  Kolkata Knight Riders           35               0
# ...

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    str
#  3   date             636 non-null    str
#  4   team1            636 non-null    str
#  5   team2            636 non-null    str
#  6   toss_winner      636 non-null    str
#  7   toss_decision    636 non-null    str
#  8   result           636 non-null    str
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    str
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    str
#  14  venue            636 non-null    str
#  15  umpire1          635 non-null    str
#  16  umpire2          635 non-null    str
#  17  umpire3          0 non-null      float64
# ...

# %%
movies.isnull().sum() # this eturns the exact number of missing values in columns
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
movies.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
# corelation means aik cheex ke brhne ya km hone se kia dusre cheex pr farq pr rh hai
# kon sa input column output pr koi asar nhi daal rha hai to generlly ap unko hata dete ho
# corelation sirf nummeric columns ka hi niklta hai
# -1 to 1
# -ve means inversely corelated
# + means both increase or decrease
movies.corr(numeric_only=True)
movies.corr(numeric_only=True)["id"]
# Out:
# id                1.000000
# season            0.471087
# dl_applied        0.024281
# win_by_runs      -0.010263
# win_by_wickets   -0.015510
# umpire3                NaN
# Name: id, dtype: float64
